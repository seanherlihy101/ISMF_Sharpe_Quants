# %%
# !git --version
# Out:
# git version 2.53.0.windows.1

# %%
# !cd
# Out:
# C:\Users\seanh\OneDrive - University College Cork\ISMF Quant 2025_26

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/seanh/OneDrive - University College Cork/ISMF Quant 2025_26/.git/

# %%
# !git remote add origin https://github.com/username/repository-name.git
